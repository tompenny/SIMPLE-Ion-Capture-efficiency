# %%
import numpy as np
import matplotlib.pyplot as plt
#import SIMION_utils as su
import importlib
import pandas as pd

# %%
base = 'D:/Simulation Data/SIMION/240812/'
files = ['run3', 'run4', 'run5', 'run6', 'run7', 'run8', 'run9']
ftype = '.csv'
#filename = base+files[0]+ftype
#data = pd.read_csv(filename, names=list('abcdefghij'))

# %%
effs = []
errs = []
for file in files:
    filename = base+file+ftype
    data = pd.read_csv(filename, names=list('abcdefghij')) 
    if file == 'run3':
        da = np.array([i for i in data.values[34:, 2:5] if i[0] != 'stopped after max_time' ])[::2].astype('float')[:, :]
        da2 = np.array([i for i in data.values[35:, 2:5] if i[0] != 'stopped after max_time' ])[::2].astype('float')[:, :]
    else:
        da = np.array([i for i in data.values[26:, 2:5] if i[0] != 'stopped after max_time' ])[::2].astype('float')[:, :]
        da2 = np.array([i for i in data.values[27:, 2:5] if i[0] != 'stopped after max_time' ])[::2].astype('float')[:, :]
    i = 0
    j = 0
    indices = []
    indices2 = []
    effs_tmp = []
    for l in range(100):
        da_tmp = da[l*10:(l+1)*10]
        for n, k in enumerate(da_tmp):
            if np.sqrt((k[0]-6.5)**2 + (k[1]-6.5)**2 + k[2]**2)<1:
                i+=1
                if n != 0:
                    indices.append(n)
            else:
                j +=1
                if n != 0:
                    indices2.append(n)
        eff = i/(i+j)
        effs_tmp.append(eff)
    effs.append(np.mean(effs_tmp))
    errs.append(np.std(effs_tmp)/np.sqrt(1))

# %%
press = [15, 10, 5, 2, 1, 4, 3]

# %%
plt.plot(press, effs, 'o')

# %%
base = 'D:/Simulation Data/SIMION/240812/'
files = ['run10', 'run11', 'run12', 'run13', 'run14', 'run15', 'run16']
ftype = '.csv'
#filename = base+files[0]+ftype
#data = pd.read_csv(filename, names=list('abcdefghij'))

# %%
effs2 = []
errs2 = []
for file in files:
    filename = base+file+ftype
    data = pd.read_csv(filename, names=list('abcdefghij')) 
    if file == 'run3':
        da = np.array([i for i in data.values[34:, 2:5] if i[0] != 'stopped after max_time' ])[::2].astype('float')[:, :]
        da2 = np.array([i for i in data.values[35:, 2:5] if i[0] != 'stopped after max_time' ])[::2].astype('float')[:, :]
    else:
        da = np.array([i for i in data.values[26:, 2:5] if i[0] != 'stopped after max_time' ])[::2].astype('float')[:, :]
        da2 = np.array([i for i in data.values[27:, 2:5] if i[0] != 'stopped after max_time' ])[::2].astype('float')[:, :]
    i = 0
    j = 0
    indices = []
    indices2 = []
    effs_tmp = []
    for l in range(100):
        da_tmp = da[l*10:(l+1)*10]
        for n, k in enumerate(da_tmp):
            if np.sqrt((k[0]-6.5)**2 + (k[1]-6.5)**2 + k[2]**2)<1:
                i+=1
                if n != 0:
                    indices.append(n)
            else:
                j +=1
                if n != 0:
                    indices2.append(n)
        eff = i/(i+j)
        effs_tmp.append(eff)
    effs2.append(np.mean(effs_tmp))
    errs2.append(np.std(effs_tmp)/np.sqrt(1))

# %%
press2 = [15, 10, 5, 4, 3, 2, 1]

# %%
plt.errorbar(press2, effs2, yerr = errs2, marker =  'o', linestyle = 'none', capsize = 6, label = 'Nitrogen molecule - single charge')
plt.errorbar(press, effs, yerr = errs, marker = 'o', linestyle = 'none', capsize = 6, label = 'Polonium ion')
plt.legend()
plt.ylabel('Capture efficiency')
plt.xlabel('Pressure (Torr)')
# Out:
# Text(0.5, 0, 'Pressure (Torr)')

# %%
base = 'D:/Simulation Data/SIMION/240812/'
files = ['run17', 'run18', 'run19', 'run20', 'run21']
ftype = '.csv'
#filename = base+files[0]+ftype
#data = pd.read_csv(filename, names=list('abcdefghij'))

# %%
effs3 = []
errs3 = []
for file in files:
    filename = base+file+ftype
    data = pd.read_csv(filename, names=list('abcdefghij')) 
    if file == 'run3':
        da = np.array([i for i in data.values[34:, 2:5] if i[0] != 'stopped after max_time' ])[::2].astype('float')[:, :]
        da2 = np.array([i for i in data.values[35:, 2:5] if i[0] != 'stopped after max_time' ])[::2].astype('float')[:, :]
    else:
        da = np.array([i for i in data.values[26:, 2:5] if i[0] != 'stopped after max_time' ])[::2].astype('float')[:, :]
        da2 = np.array([i for i in data.values[27:, 2:5] if i[0] != 'stopped after max_time' ])[::2].astype('float')[:, :]
    i = 0
    j = 0
    indices = []
    indices2 = []
    effs_tmp = []
    for l in range(100):
        da_tmp = da[l*10:(l+1)*10]
        for n, k in enumerate(da_tmp):
            if np.sqrt((k[0]-6.5)**2 + (k[1]-6.5)**2 + k[2]**2)<1:
                i+=1
                if n != 0:
                    indices.append(n)
            else:
                j +=1
                if n != 0:
                    indices2.append(n)
        eff = i/(i+j)
        effs_tmp.append(eff)
    effs3.append(np.mean(effs_tmp))
    errs3.append(np.std(effs_tmp)/np.sqrt(1))

# %%
base = 'D:/Simulation Data/SIMION/240812/'
files = ['run22', 'run23', 'run24', 'run25', 'run26']
ftype = '.csv'
#filename = base+files[0]+ftype
#data = pd.read_csv(filename, names=list('abcdefghij'))

# %%
effs4 = []
errs4 = []
for file in files:
    filename = base+file+ftype
    data = pd.read_csv(filename, names=list('abcdefghij')) 
    if file == 'run3':
        da = np.array([i for i in data.values[34:, 2:5] if i[0] != 'stopped after max_time' ])[::2].astype('float')[:, :]
        da2 = np.array([i for i in data.values[35:, 2:5] if i[0] != 'stopped after max_time' ])[::2].astype('float')[:, :]
    else:
        da = np.array([i for i in data.values[26:, 2:5] if i[0] != 'stopped after max_time' ])[::2].astype('float')[:, :]
        da2 = np.array([i for i in data.values[27:, 2:5] if i[0] != 'stopped after max_time' ])[::2].astype('float')[:, :]
    i = 0
    j = 0
    indices = []
    indices2 = []
    effs_tmp = []
    for l in range(100):
        da_tmp = da[l*10:(l+1)*10]
        for n, k in enumerate(da_tmp):
            if np.sqrt((k[0]-6.5)**2 + (k[1]-6.5)**2 + k[2]**2)<1:
                i+=1
                if n != 0:
                    indices.append(n)
            else:
                j +=1
                if n != 0:
                    indices2.append(n)
        eff = i/(i+j)
        effs_tmp.append(eff)
    effs4.append(np.mean(effs_tmp))
    errs4.append(np.std(effs_tmp)/np.sqrt(1))

# %%
volt = [175, 150, 125, 100, 75]

# %%
plt.errorbar(volt, effs4, yerr = errs4, marker =  'o', linestyle = 'none', capsize = 6, label = 'Nitrogen molecule - single charge')
plt.errorbar(volt, effs3, yerr = errs3, marker = 'o', linestyle = 'none', capsize = 6, label = 'Polonium ion')
plt.legend()
plt.ylabel('Capture efficiency')
plt.xlabel('Volts (V)')
# Out:
# Text(0.5, 0, 'Volts (V)')

# %%
base = 'D:/Simulation Data/SIMION/240812/'
files = ['run27', 'run28', 'run29', 'run30', 'run31', 'run32', 'run33', 'run34', 'run35']
ftype = '.csv'
#filename = base+files[0]+ftype
#data = pd.read_csv(filename, names=list('abcdefghij'))

# %%
effs5 = []
errs5 = []
for file in files:
    filename = base+file+ftype
    data = pd.read_csv(filename, names=list('abcdefghij')) 
    if file == 'run3':
        da = np.array([i for i in data.values[34:, 2:5] if i[0] != 'stopped after max_time' ])[::2].astype('float')[:, :]
        da2 = np.array([i for i in data.values[35:, 2:5] if i[0] != 'stopped after max_time' ])[::2].astype('float')[:, :]
    else:
        da = np.array([i for i in data.values[26:, 2:5] if i[0] != 'stopped after max_time' ])[::2].astype('float')[:, :]
        da2 = np.array([i for i in data.values[27:, 2:5] if i[0] != 'stopped after max_time' ])[::2].astype('float')[:, :]
    i = 0
    j = 0
    indices = []
    indices2 = []
    effs_tmp = []
    for l in range(100):
        da_tmp = da[l*10:(l+1)*10]
        for n, k in enumerate(da_tmp):
            if np.sqrt((k[0]-6.5)**2 + (k[1]-6.5)**2 + k[2]**2)<1:
                i+=1
                if n != 0:
                    indices.append(n)
            else:
                j +=1
                if n != 0:
                    indices2.append(n)
        eff = i/(i+j)
        effs_tmp.append(eff)
    effs5.append(np.mean(effs_tmp))
    errs5.append(np.std(effs_tmp)/np.sqrt(1))

# %%
sp_volt = [10, 100, 1000, 10000, 0, -10, -100, -1000, -10000]

# %%
plt.errorbar(sp_volt[:4], effs5[:4], yerr = errs5[:4], marker = 'o', linestyle = 'none', capsize = 6, label = 'Electrons on sphere')
plt.errorbar(sp_volt[:4], effs5[5:], yerr = errs5[5:], marker = 'o', linestyle = 'none', capsize = 6, label = 'Postive charge on sphere')
plt.legend()
plt.ylabel('Capture efficiency')
plt.xlabel('Charges (e)')
plt.xscale('log')

# %%
base = 'D:/Simulation Data/SIMION/240812/'
files = ['run36', 'run37', 'run38', 'run39', 'run40']
ftype = '.csv'
#filename = base+files[0]+ftype
#data = pd.read_csv(filename, names=list('abcdefghij'))

# %%
effs6 = []
errs6 = []
for file in files:
    filename = base+file+ftype
    data = pd.read_csv(filename, names=list('abcdefghij')) 
    if file == 'run3':
        da = np.array([i for i in data.values[34:, 2:5] if i[0] != 'stopped after max_time' ])[::2].astype('float')[:, :]
        da2 = np.array([i for i in data.values[35:, 2:5] if i[0] != 'stopped after max_time' ])[::2].astype('float')[:, :]
    else:
        da = np.array([i for i in data.values[29:, 2:5] if i[0] != 'stopped after max_time' ])[::2].astype('float')[:, :]
        da2 = np.array([i for i in data.values[30:, 2:5] if i[0] != 'stopped after max_time' ])[::2].astype('float')[:, :]
    i = 0
    j = 0
    indices = []
    indices2 = []
    effs_tmp = []
    for l in range(100):
        da_tmp = da[l*10:(l+1)*10]
        for n, k in enumerate(da_tmp):
            if np.sqrt((k[0]-6.5)**2 + (k[1]-6.5)**2 + k[2]**2)<1:
                i+=1
                if n != 0:
                    indices.append(n)
            else:
                j +=1
                if n != 0:
                    indices2.append(n)
        eff = i/(i+j)
        effs_tmp.append(eff)
    effs6.append(np.mean(effs_tmp))
    errs6.append(np.std(effs_tmp)/np.sqrt(1))

# %%
volt = [175, 150, 125, 100, 75]

# %%
plt.errorbar(volt, effs6, yerr = errs6, marker =  'o', linestyle = 'none', capsize = 6, label = 'Two rings')
plt.errorbar(volt, effs3, yerr = errs3, marker = 'o', linestyle = 'none', capsize = 6, label = 'Many rings')
plt.legend()
plt.ylabel('Capture efficiency')
plt.xlabel('Volts (V)')
# Out:
# Text(0.5, 0, 'Volts (V)')

# %% [markdown]
# Looks like it doesn't matter what the particle charge is
#
# I think I need to do a finer simulation to double check this kind of thing
#
# But first I want to check if we can take out some of the middle rings.
#
# Going to repeat volts vs efficiency to test this

# %%
V_cham = 0.062484*2*0.025**2*np.pi + 0.062484*0.025**2*np.pi + 0.07*0.025**2*np.pi + 0.015*0.025**2*np.pi
print(V_cham)
V_loader = 0.03*0.0055**2*np.pi*2
print(V_loader)
eff1 = V_loader/V_cham
# Out:
# 0.000534958251034904
# 5.701990666265474e-06

# %%
eff1*effs[0]*5000
# Out:
# 19.262300637665838

# %%
time = np.linspace(0, 100*3600, 1000)
lam_Rn = 1/(3600*24*365*1.9)
lam_Pb = 1/10.2/3600
N_Rn0 = 5000/lam_Rn
N_Pb = N_Rn0*lam_Rn/(lam_Pb-lam_Rn)*(np.exp(-lam_Rn*time) - np.exp(-lam_Pb*time))

# %%
plt.plot(time/3600, lam_Pb*N_Pb*eff1*effs[0]*0.01)

# %% [markdown]
# Okay, this is pretty much the exact same efficiency so I guess it works just fine as expected.
